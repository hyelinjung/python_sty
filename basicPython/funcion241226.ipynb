# %%
# pow
print(pow(2,3))

# round 반올림
result = round(31.5)
print(result)
# mpp 각 요소마다 적용
map(str,[1,2,3])
# 절대값 반환
abs(-4)
# 조건을 만족시키는 요소만 필터링
filter(lambda x:x>2,[2,3,4])
# 여러 이터러블을 묶어서 튜플로 반환
zip([1,2],['a','b'])
print(zip([1,2],['a','b']))
# 인덱스와 요소를 함께 반환
enumerate(['a','b'])
print(enumerate(['a','b']))
# Out:
# 8
# 32
# ...
# [1, 2, 3]

# %%
# list
list =['apple','bbb','ccc']
list.extend(['aaa','ttt'])
list.append('yyy')
list.insert(1,'addWith index')
list.remove('apple')
list.pop('원하는 위치..인덱스사용, 공백시 마지막 요소')
list.sort()
list.count('해당 인자의 개수를 반환') 
list.index('요소를 정하면 해당 요소의 인덱스 반환')
print(list)
# Out:
# ['addWith index', 'bbb', 'ccc', 'aaa', 'ttt', 'yyy']

# %%
# 문자열
text ='Hello World'
text.lower()
# 공백 제거
_text=' Hello World '
print(_text.strip())
# 문자열 -> 리스트
_text2="apple,banana,cherry"
retult =_text2.split(',')
print(result)
# 리스트-> 문자열
print(','.join(result))
# Out:
# Hello World
# ['apple', 'banana', 'cherry']
