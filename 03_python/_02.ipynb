# %%
import pandas as pd
import numpy as np

input =pd.read_csv('../dataSet/diabetes.csv')
print(input.head())
input.loc[0:5,'Age':]
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1
#    Age  Outcome
# 0   50        1
# 1   31        0
# 2   32        1
# 3   21        0
# 4   33        1
# 5   30        0

# %%
input.groupby('Pregnancies').mean()
# Out:
#                 Glucose  BloodPressure  SkinThickness     Insulin        BMI  \
# Pregnancies
# 0            123.000000      67.153153      22.270270   81.675676  34.290090
# 1            112.748148      67.792593      24.437037   98.674074  31.372593
# 2            110.796117      63.252427      21.601942   85.844660  30.583495
# 3            123.586667      66.586667      20.080000   87.453333  30.425333
# 4            125.117647      70.029412      15.882353   69.441176  32.141176
# 5            118.859649      76.210526      17.385965   57.298246  33.192982
# 6            120.800000      68.420000      17.640000   63.580000  30.290000
# 7            136.444444      70.777778      20.288889   84.466667  32.631111
# 8            131.736842      75.184211      17.315789   92.815789  31.568421
# 9            131.392857      77.892857      20.892857   62.428571  31.707143
# 10           120.916667      70.208333      15.708333   34.791667  30.641667
# ...

# %%
input.isna().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 3행 3열로 0~1 난수로 배열 생성
arr = np.random.rand(3,3)
arr
# Out:
# array([[0.66539379, 0.19781286, 0.99652714],
#        [0.35851448, 0.384557  , 0.50083358],
#        [0.19866837, 0.76313981, 0.88011026]])

# %%
# 1행 9열로 배열 형태 변경
arr = arr.reshape(1,9)
arr
# Out:
# array([[0.66539379, 0.19781286, 0.99652714, 0.35851448, 0.384557  ,
#         0.50083358, 0.19866837, 0.76313981, 0.88011026]])

# %%
# 값의 합계 평균 표쥰편차 구하기
print(np.sum([1,2,3]))
print(np.mean([1,2,3]))
print(np.std([1,2,3]))
# Out:
# 6
# 2.0
# 0.816496580927726

# %% [markdown]
# # 데이터분석 &시각화

# %%
# 데이터 가져오기 pandas, 시각화 matplotlib,seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 파일 읽기 -> 위에서 5개 출력
input = pd.read_csv('../dataSet/diabetes.csv')
input.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
# 맨 밑에서 5개 출력
input.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
# 데이터프레임의 기본적인 통계 정보 확인
input.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
# 데이터프레임의 요약 정보 확인(인덱스,컬럼명. 데이터타입 등)
input.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
# 데이터프레임의 상관관계분석 (값이 1이랑 가까울수록 높은 관계룰 가지고 있음)
input.corr()
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
# 분석한 상관관계를 seborn 라이브러리를 사용해 hratmap 작성(plt를 사용해 보여줌)
# 인자 true 값이면 글자표시
sns.heatmap(input.corr(), annot=True)
# 그래프 출력
plt.show()

# %%
# 히스토그램 생성 (히스토그램은 막대그래프를 이용해 연속형 데이터의 분포를 나타냄)
# figsize는 그래프를 나타낼 도화지의 가로 세로 크기를 의미
input.hist(figsize=(10,8))
plt.show()

# %%
# 데이터프레임의 널값이 존재하는지 합계를 통해 확인
input.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
# 만약 결측치(널값)이 있다면 fillna를 통해 채워준다
# fillna(평균값으로)
input.fillna(input.mean(), inplace=True)
input
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
# numpy에 linspace메서드를 통해 (start, stop, num -> 0부터 10까지 100개의 간격으로 요소 생성)
x = np.linspace(0,10,100)
# 삼각함수 sin을 사용
y= np.sin(x)
# plot는 선 그래프를 그리는 메서드
plt.plot(x,y)
plt.xlabel('x')
plt.ylabel('y')
# 그래프 제목 설정
plt.title('Sine Wave')
plt.show()

# %%
# tips는 seaborn 라이브러리를 설치하면서 내장되어있는 샘플 데이터셋임
# load_dataset을 통해 tips 데이터셋을 불러옴
tips = sns.load_dataset('tips')
sns.displot(tips['tip'], kde=True)
plt.show()

# %%
# 성별에 따른 팁에 대한 박스플롯
sns.boxplot(x='sex', y='tip', data=tips)
plt.show()

# %%
# 산점도 -> 관계를 나타내는 그래프
# 상관관계 분석에 용이
sns.scatterplot(x='total_bill',y='tip',data=tips)
plt.show()
