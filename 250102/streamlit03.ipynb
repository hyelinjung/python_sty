# %%
import streamlit as st
import pandas as pd
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
#타이틀 설정
st.title('iris 꽃 분류기')
# Out:
# 2025-01-02 14:46:23.389 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:23.870
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run c:\study_python_3106\.venv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-01-02 14:46:23.872 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()

# %%
# 데이터 로드
iris = load_iris()
X = pd.DataFrame(iris.data, columns=iris.feature_names)
y= pd.Series(iris.target_names[iris.target], name='species')

# %%
# 사이드바 생성
st.sidebar.header('사용자 입력 파라미터')
# Out:
# 2025-01-02 14:46:29.881 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:29.882 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator(_root_container=1, _parent=DeltaGenerator())

# %%
# 슬라이더로 하이퍼파라미터 조정
n_estimators =st.sidebar.slider('트리 개수',1,100,10)
max_depth = st.sidebar.slider('최대깊이',1,10,3)
# Out:
# 2025-01-02 14:46:32.407 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.409 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.410 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.411 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.412 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.413 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:32.414 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
#데이터 분할
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=42)

# %%
# 모델학습
clf = RandomForestClassifier(n_estimators=n_estimators, max_depth=max_depth,random_state=42)
clf.fit(X_train,y_train)
# Out:
# RandomForestClassifier(max_depth=3, n_estimators=10, random_state=42)

# %%
# 정확도 계산
y_pred = clf.predict(X_test)
accuracy = accuracy_score(y_test,y_pred)

# %%
# 결과표시
st.write(f'모델 정확도: {accuracy * 100:.2f}% ')
# Out:
# 2025-01-02 14:46:42.678 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:42.679 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:42.680 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:42.681 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
# 특징 중요도 시각화
st.subheader('특징 중요도')
feature_importance = pd.DataFrame({
    '특징': X.columns,
    '중요도': clf.feature_importances_
}).sort_values('중요도', ascending=False)

print(feature_importance)

st.bar_chart(feature_importance.set_index('특징'))
# Out:
# 2025-01-02 14:46:47.110 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:47.111 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
#                   특징       중요도
# 2  petal length (cm)  0.433473
# 3   petal width (cm)  0.404982
# 0  sepal length (cm)  0.141489
# 1   sepal width (cm)  0.020056
# 2025-01-02 14:46:47.481 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-01-02 14:46:47.482 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# DeltaGenerator()
